# %%
import requests

# %%
r = requests.get('https://abbreviations.yourdictionary.com/articles/state-abbrev.html')

# %%
print(r.text[:])
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en" itemscope="itemscope" itemtype="http://schema.org/Article"> <!--<![endif]-->
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
#     <meta charset="utf-8" />
#     <meta http-equiv="x-ua-compatible" content="IE=edge" />
#
#     <link href='//fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,400,300,600,700' rel='stylesheet' type='text/css'>
#     <link href='//fonts.googleapis.com/css?family=Bitter:400,700' rel='stylesheet' type='text/css'>
#     <link href="//fonts.googleapis.com/css?family=Fira+Sans+Condensed:400,400i" rel="stylesheet">
#
#     <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0">
#     <meta name="google-signin-client_id" content="578806447330.apps.googleusercontent.com">
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
results = soup.find_all('li')

# %%
len(results)
# Out:
# 250

# %%
f = results[0:51]
print(f)
# Out:
# [<li>Alabama - AL </li>, <li>Alaska - AK </li>, <li>Arizona - AZ </li>, <li>Arkansas - AR </li>, <li>California - CA </li>, <li>Colorado - CO </li>, <li>Connecticut - CT </li>, <li>Delaware - DE </li>, <li>Florida - FL </li>, <li>Georgia - GA </li>, <li>Hawaii - HI </li>, <li>Idaho - ID </li>, <li>Illinois - IL </li>, <li>Indiana - IN </li>, <li>Iowa - IA </li>, <li>Kansas - KS </li>, <li>Kentucky - KY </li>, <li>Louisiana - LA </li>, <li>Maine - ME </li>, <li>Maryland - MD </li>, <li>Massachusetts - MA </li>, <li>Michigan - MI </li>, <li>Minnesota - MN </li>, <li>Mississippi - MS </li>, <li>Missouri - MO </li>, <li>Montana - MT </li>, <li>Nebraska - NE </li>, <li>Nevada - NV </li>, <li>New Hampshire - NH </li>, <li>New Jersey - NJ </li>, <li>New Mexico - NM </li>, <li>New York - NY </li>, <li>North Carolina - NC </li>, <li>North Dakota - ND </li>, <li>Ohio - OH </li>, <li>Oklahoma - OK </li>, <li>Oregon - OR </li>, <li>Pennsylvania - PA </li>, <li>Rhode Island - RI </li>, <li>South 
# ...

# %%
states = []
for x in f:
    states.append("{title:"+'\"'+ x+'\"},')
print(states)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-90e928a697a5> in <module>
#       1 states = []
#       2 for x in f:
# ----> 3     states.append("{title:"+'\"'+ x+'\"},')
#       4 print(states)
#
# TypeError: can only concatenate str (not "Tag") to str

# %%
official = ''.join(countries)
print(official)
# Out:
# {title:"Afghanistan"},{title:"Albania"},{title:"Algeria"},{title:"Andorra"},{title:"Angola"},{title:"Antigua and Barbuda"},{title:"Argentina"},{title:"Armenia"},{title:"Australia"},{title:"Austria"},{title:"Azerbaijan"},{title:"The Bahamas"},{title:"Bahrain"},{title:"Bangladesh"},{title:"Barbados"},{title:"Belarus"},{title:"Belgium"},{title:"Belize"},{title:"Benin"},{title:"Bhutan"},{title:"Bolivia"},{title:"Bosnia and Herzegovina"},{title:"Botswana"},{title:"Brazil"},{title:"Brunei"},{title:"Bulgaria"},{title:"Burkina Faso"},{title:"Burundi"},{title:"Cabo Verde"},{title:"Cambodia"},{title:"Cameroon"},{title:"Canada"},{title:"Central African Republic"},{title:"Chad"},{title:"Chile"},{title:"China"},{title:"Colombia"},{title:"Comoros"},{title:"Congo, Democratic  Republic of the"},{title:"Congo, Republic of the"},{title:"Costa Rica"},{title:"Côte d’Ivoire"},{title:"Croatia"},{title:"Cuba"},{title:"Cyprus"},{title:"Czech Republic"},{title:"Denmark"},{title:"Djibouti"},{title:"Dominica"}
# ...

# %%
first_result.contents[1][1:-2]
# Out:
# "I wasn't a fan of Iraq. I didn't want to go into Iraq."

# %%
first_result.find('a').text[1:-2]
# Out:
# 'He was for an invasion before he was against it'

# %%
first_result.find('a')['href']
# Out:
# 'https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the'

# %%
allRecords = []
for x in results:
    date = x.find('strong').text[0:-1] + ', 2017'
    lie  = x.contents[1][1:-2]
    explanation = x.find('a').text[1:-2]
    link = x.find('a')['href']
    allRecords.append((date,lie,explanation,link))

# %%
len(allRecords)
# Out:
# 180

# %%
uniNames
# Out:
# ["{title:'A.T. Still University'},",
#  "{title:'Abilene Christian University'},",
#  "{title:'Abraham Baldwin Agricultural College'},",
#  "{title:'Academy of Art University'},",
#  "{title:'Adams State University'},",
#  "{title:'Adelphi University'},",
#  "{title:'Adler Graduate School'},",
#  "{title:'Adler University'},",
#  "{title:'Adrian College'},",
#  "{title:'Adventist University of Health Sciences'},",
#  "{title:'Agnes Scott College'},",
#  "{title:'Air Force Institute of Technology'},",
#  "{title:'Alabama A&M University'},",
#  "{title:'Alabama State University'},",
#  "{title:'Alaska Bible College'},",
#  "{title:'Alaska Pacific University'},",
#  "{title:'Albany College of Pharmacy and Health Sciences'},",
#  "{title:'Albany Law School'},",
#  "{title:'Albany Medical College'},",
#  "{title:'Albany State University'},",
#  "{title:'Albertus Magnus College'},",
#  "{title:'Albion College'},",
#  "{title:'Albright College'},",
#  "{title:'Alcorn State University'},",
# ...

# %%
import pandas as pd
df = pd.DataFrame(official)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-32c726e54ae9> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame(official)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
df
# Out:
#                                                       0
# 0                      {title:'A.T. Still University'},
# 1               {title:'Abilene Christian University'},
# 2       {title:'Abraham Baldwin Agricultural College'},
# 3                  {title:'Academy of Art University'},
# 4                     {title:'Adams State University'},
# 5                         {title:'Adelphi University'},
# 6                      {title:'Adler Graduate School'},
# 7                           {title:'Adler University'},
# 8                             {title:'Adrian College'},
# 9     {title:'Adventist University of Health Science...
# 10                       {title:'Agnes Scott College'},
# 11         {title:'Air Force Institute of Technology'},
# 12                    {title:'Alabama A&M University'},
# 13                  {title:'Alabama State University'},
# 14                      {title:'Alaska Bible College'},
# 15                 {title:'Alaska Pacific University'},
# ...

# %%
df.tail()
# Out:
#               date                                                lie  \
# 175  Oct. 25, 2017      We have trade deficits with almost everybody.
# 176  Oct. 27, 2017  Wacky & totally unhinged Tom Steyer, who has b...
# 177   Nov. 1, 2017  Again, we're the highest-taxed nation, just ab...
# 178   Nov. 7, 2017  When you look at the city with the strongest g...
# 179  Nov. 11, 2017  I'd rather have him  – you know, work with him...
#
#                                            explanation  \
# 175  We have trade surpluses with more than 100 cou...
# 176  Steyer has financially supported many winning ...
# 177                                          We're not
# 178  Several other cities, including New York and L...
# 179  There is no evidence that Democrats "set up" R...
#
#                                                   link
# 175  https://www.bea.gov/newsreleases/international...
# 176  https://www.opensecrets.org/donor-lookup/resul...
# ...

# %%
df.head()
# Out:
#                                                  0
# 0                 {title:'A.T. Still University'},
# 1          {title:'Abilene Christian University'},
# 2  {title:'Abraham Baldwin Agricultural College'},
# 3             {title:'Academy of Art University'},
# 4                {title:'Adams State University'},

# %%
df.to_csv('university-names-in-json-format',index=False,encoding='utf-8')

# %%
trump = pd.read_csv('trumpLies.csv',parse_dates=['date'],encoding='utf-8')

# %%
trump.head()
# Out:
#         date                                                lie  \
# 0 2017-01-21  I wasn't a fan of Iraq. I didn't want to go in...
# 1 2017-01-21  A reporter for Time magazine — and I have been...
# 2 2017-01-23  Between 3 million and 5 million illegal votes ...
# 3 2017-01-25  Now, the audience was the biggest ever. But th...
# 4 2017-01-25  Take a look at the Pew reports (which show vot...
#
#                                          explanation  \
# 0    He was for an invasion before he was against it
# 1  Trump was on the cover 11 times and Nixon appe...
# 2              There's no evidence of illegal voting
# 3  Official aerial photos show Obama's 2009 inaug...
# 4             The report never mentioned voter fraud
#
#                                                 link
# 0  https://www.buzzfeed.com/andrewkaczynski/in-20...
# 1  http://nation.time.com/2013/11/06/10-things-yo...
# 2  https://www.nytimes.com/2017/01/23/us/politics...
# ...
